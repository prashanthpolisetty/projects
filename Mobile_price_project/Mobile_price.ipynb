# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

path = "D:/ML/projects/Mobile Phone Pricing/dataset.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df.drop(['blue','talk_time', 'clock_speed' , 'm_dep','mobile_wt', 'sc_h','sc_w'], axis=1, inplace=True)  # modifies the original df

# %%
df.isnull().sum()
# Out:
# battery_power    0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df = df.rename(columns={'pc': 'camara', 'fc': ' Front Camera'})

# %%
df.describe()
# Out:
#        battery_power     dual_sim   Front Camera       four_g   int_memory  \
# count    2000.000000  2000.000000    2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.509500       4.309500     0.521500    32.046500
# std       439.418206     0.500035       4.341444     0.499662    18.145715
# min       501.000000     0.000000       0.000000     0.000000     2.000000
# 25%       851.750000     0.000000       1.000000     0.000000    16.000000
# 50%      1226.000000     1.000000       3.000000     1.000000    32.000000
# 75%      1615.250000     1.000000       7.000000     1.000000    48.000000
# max      1998.000000     1.000000      19.000000     1.000000    64.000000
#
#            n_cores       camara    px_height     px_width          ram  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      4.520500     9.916500   645.108000  1251.515500  2124.213000
# std       2.287837     6.064315   443.780811   432.199447  1084.732044
# ...

# %%
df.dtypes
# Out:
# battery_power    int64
# dual_sim         int64
#  Front Camera    int64
# four_g           int64
# int_memory       int64
# n_cores          int64
# camara           int64
# px_height        int64
# px_width         int64
# ram              int64
# three_g          int64
# touch_screen     int64
# wifi             int64
# price_range      int64
# dtype: object

# %%
df.head()
# Out:
#    battery_power  dual_sim   Front Camera  four_g  int_memory  n_cores  \
# 0            842         0              1       0           7        2
# 1           1021         1              0       1          53        3
# 2            563         1              2       1          41        5
# 3            615         0              0       0          10        6
# 4           1821         0             13       1          44        2
#
#    camara  px_height  px_width   ram  three_g  touch_screen  wifi  price_range
# 0       2         20       756  2549        0             0     1            1
# 1       6        905      1988  2631        1             1     0            2
# 2       6       1263      1716  2603        1             1     0            2
# 3       9       1216      1786  2769        1             0     0            2
# 4      14       1208      1212  1411        1             1     0            1

# %%
# Assuming your data is in a Pandas DataFrame called 'df'
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title('Correlation Matrix')
plt.show()

# %%
sns.boxplot(x='ram', y='battery_power', data=df)
plt.title("Battery Power by Brand")
plt.show()

# %%
sns.histplot(data=df, x='battery_power', bins=5, kde=True, color='green')
plt.title("Battery Power Distribution")
plt.xlabel("Battery Power")
plt.ylabel("count")
plt.show()

# %%
sns.histplot(data=df, x='ram', bins=5, kde=True, color='green')
plt.title("Ram Distribution")
plt.xlabel("Ram")
plt.ylabel("count")
plt.show()

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                battery_power  dual_sim   Front Camera    four_g  int_memory  \
# battery_power       1.000000 -0.041847       0.033334  0.015665   -0.004004
# dual_sim           -0.041847  1.000000      -0.029123  0.003187   -0.015679
#  Front Camera       0.033334 -0.029123       1.000000 -0.016560   -0.029133
# four_g              0.015665  0.003187      -0.016560  1.000000    0.008690
# int_memory         -0.004004 -0.015679      -0.029133  0.008690    1.000000
# n_cores            -0.029727 -0.024658      -0.013356 -0.029706   -0.028310
# camara              0.031441 -0.017143       0.644595 -0.005598   -0.033273
# px_height           0.014901 -0.020875      -0.009990 -0.019236    0.010441
# px_width           -0.008402  0.014291      -0.005176  0.007448   -0.008335
# ram                -0.000653  0.041072       0.015099  0.007313    0.032813
# three_g             0.011522 -0.014008       0.001793  0.584246   -0.009366
# ...

# %%
correlation = df['battery_power'].corr(df['price_range'])
print("Correlation between battery_power and price_range:", correlation)
# Out:
# Correlation between battery_power and price_range: 0.20072261211373102

# %%
correlation = df['camara'].corr(df['Front Camera'])
print("Correlation between camara and Front Camera:", correlation)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Front Camera'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 correlation = df['camara'].corr(df['Front Camera'])
# ...

# %%
correlation = df['price_range'].corr(df['n_cores'])
print("Correlation between battery_power and ram:", correlation)
# Out:
# Correlation between battery_power and ram: 0.004399274799457284

# %%
# 1. Screen Size
df['screen_size'] = df['px_height'] / df['px_width']

# 2. Total Memory
df['total_memory'] = df['int_memory'] + df['ram']

# 3. Camera Index (Simplified)
df['camera_index'] = df['camara']

# 4. Interaction Term
df['cores_battery'] = df['n_cores'] * df['battery_power']

# %%
df.describe()
# Out:
#        battery_power     dual_sim   Front Camera       four_g   int_memory  \
# count    2000.000000  2000.000000    2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.509500       4.309500     0.521500    32.046500
# std       439.418206     0.500035       4.341444     0.499662    18.145715
# min       501.000000     0.000000       0.000000     0.000000     2.000000
# 25%       851.750000     0.000000       1.000000     0.000000    16.000000
# 50%      1226.000000     1.000000       3.000000     1.000000    32.000000
# 75%      1615.250000     1.000000       7.000000     1.000000    48.000000
# max      1998.000000     1.000000      19.000000     1.000000    64.000000
#
#            n_cores       camara    px_height     px_width          ram  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      4.520500     9.916500   645.108000  1251.515500  2124.213000
# std       2.287837     6.064315   443.780811   432.199447  1084.732044
# ...

# %%
df.drop(['px_height','px_width','ram','n_cores','battery_power','int_memory','camara'],axis=1,inplace = True)

# %%
df.describe()
# Out:
#           dual_sim   Front Camera       four_g      three_g  touch_screen  \
# count  2000.000000    2000.000000  2000.000000  2000.000000   2000.000000
# mean      0.509500       4.309500     0.521500     0.761500      0.503000
# std       0.500035       4.341444     0.499662     0.426273      0.500116
# min       0.000000       0.000000     0.000000     0.000000      0.000000
# 25%       0.000000       1.000000     0.000000     1.000000      0.000000
# 50%       1.000000       3.000000     1.000000     1.000000      1.000000
# 75%       1.000000       7.000000     1.000000     1.000000      1.000000
# max       1.000000      19.000000     1.000000     1.000000      1.000000
#
#               wifi  price_range  screen_size  total_memory  camera_index  \
# count  2000.000000  2000.000000  2000.000000   2000.000000   2000.000000
# mean      0.507000     1.500000     0.515008   2156.259500      9.916500
# std       0.500076     1.118314     0.288054   1085.478978      6.064315
# ...

# %%
df.head()
# Out:
#    dual_sim   Front Camera  four_g  three_g  touch_screen  wifi  price_range  \
# 0         0              1       0        0             0     1            1
# 1         1              0       1        1             1     0            2
# 2         1              2       1        1             1     0            2
# 3         0              0       0        1             0     0            2
# 4         0             13       1        1             1     0            1
#
#    screen_size  total_memory  camera_index  cores_battery
# 0     0.026455          2556             2           1684
# 1     0.455231          2684             6           3063
# 2     0.736014          2644             6           2815
# 3     0.680851          2779             9           3690
# 4     0.996700          1455            14           3642

# %%
x = 'screen_size'
y = 'camera_index'

plt.scatter(x,y)
plt.title("scatter of data x and y")

plt.xlabel('Screen')
plt.ylabel('camera')
# Out:
# Text(0, 0.5, 'camera')

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title('Correlation Matrix')
plt.show()

# %%
df.drop(['touch_screen'],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#    dual_sim   Front Camera  four_g  three_g  wifi  price_range  screen_size  \
# 0         0              1       0        0     1            1     0.026455
# 1         1              0       1        1     0            2     0.455231
# 2         1              2       1        1     0            2     0.736014
# 3         0              0       0        1     0            2     0.680851
# 4         0             13       1        1     0            1     0.996700
# 5         1              3       0        1     0            1     0.607013
# 6         0              4       1        1     1            3     0.374263
# 7         1              0       0        1     1            0     0.445605
# 8         0              0       0        1     0            0     0.461722
# 9         1              2       1        1     0            0     0.928922
#
#    total_memory  camera_index  cores_battery
# 0          2556             2           1684
# ...

# %%
df = df.drop_duplicates()

# %%
from scipy.stats import zscore
df = df[(zscore(df.select_dtypes(include='number')) < 3).all(axis=1)]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[['total_memory', 'dual_sim']])
print(X_scaled)
# Out:
# [[ 0.36835395 -1.01918398]
#  [ 0.48630374  0.98117712]
#  [ 0.44944443  0.98117712]
#  ...
#  [ 0.86319016  0.98117712]
#  [-1.14379915 -1.01918398]
#  [ 1.66580159  0.98117712]]
